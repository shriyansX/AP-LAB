# %%
print("Hello World")
# Out:
# Hello World

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)      # Float division
print("Modulus:", a % b)       # Remainder
print("Floor Division:", a // b)  # Quotient without decimal
print("Exponent:", a ** b)     # a raised to the power b
# Out:
# Enter first number:  22
# Enter second number:  22
# Addition: 44
# Subtraction: 0
# Multiplication: 484
# Division: 1.0
# Modulus: 0
# Floor Division: 1
# Exponent: 341427877364219557396646723584

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

temp = a
a = b
b = temp

print("After swapping: a =", a, ", b =", b)
# Out:
# Enter first number:  21
# Enter second number:  12
# After swapping: a = 12 , b = 21

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print(num, "is Even")
else:
    print(num, "is Odd")
# Out:
# Enter a number:  23
# 23 is Odd
