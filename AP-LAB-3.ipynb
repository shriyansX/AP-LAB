# %%
n = int(input("Enter a number: "))
fact = 1

for i in range(1, n + 1):
    fact *= i

print("Factorial =", fact)
# Out:
# Enter a number:  3
# Factorial = 6

# %%
n = int(input("Enter number of terms: "))
a, b = 0, 1

for i in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter number of terms:  5
# 0 1 1 2 3

# %%
n = int(input("Enter number of elements: "))
lst = []

for i in range(n):
    lst.append(int(input("Enter element: ")))

largest = lst[0]
for num in lst:
    if num > largest:
        largest = num

print("Largest element =", largest)
# Out:
# Enter number of elements:  3
# Enter element:  23
# Enter element:  45
# Enter element:  323
# Largest element = 323

# %%
n = int(input("Enter number of elements: "))
lst = []

for i in range(n):
    lst.append(int(input("Enter element: ")))

unique_list = []
for item in lst:
    if item not in unique_list:
        unique_list.append(item)

print("List after removing duplicates:", unique_list)
# Out:
# Enter number of elements:  3
# Enter element:  12
# Enter element:  12
# Enter element:  45
# List after removing duplicates: [12, 45]

# %%
n = int(input("Enter number of elements: "))
lst = []

for i in range(n):
    lst.append(int(input("Enter element: ")))

largest = second_largest = -1

for num in lst:
    if num > largest:
        second_largest = largest
        largest = num
    elif num > second_largest and num != largest:
        second_largest = num

print("Second largest element =", second_largest)
# Out:
# Enter number of elements:  3
# Enter element:  123
# Enter element:  456
# Enter element:  789
# Second largest element = 456

# %%
s = input("Enter a string: ")
freq = {}

for ch in s:
    if ch in freq:
        freq[ch] += 1
    else:
        freq[ch] = 1

print("Character frequencies:")
for key, value in freq.items():
    print(key, ":", value)
# Out:
# Enter a string:  SHAJDA
# Character frequencies:
# S : 1
# H : 1
# A : 2
# J : 1
# D : 1

# %%
n = int(input("Enter number of items: "))
d = {}

for i in range(n):
    key = input("Enter key: ")
    value = int(input("Enter value: "))
    d[key] = value

max_key = None
max_value = -1

for k, v in d.items():
    if v > max_value:
        max_value = v
        max_key = k

print("Key with maximum value:", max_key)
# Out:
# Enter number of items:  3
# Enter key:  a
# Enter value:  12
# Enter key:  b
# Enter value:  24
# Enter key:  c
# Enter value:  10
# Key with maximum value: b

# %%
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact

num = int(input("Enter a number: "))
print("Factorial =", factorial(num))
# Out:
# Enter a number:  5
# Factorial = 120

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

num = int(input("Enter a number: "))
print("Factorial =", factorial(num))
# Out:
# Enter a number:  5
# Factorial = 120

# %%
class Student:
    def __init__(self, name, roll, branch):
        self.name = name
        self.roll = roll
        self.branch = branch

s1 = Student("Shriyans", 2306146, "IT")

print("Name:", s1.name)
print("Roll No:", s1.roll)
print("Branch:", s1.branch)
# Out:
# Name: Shriyans
# Roll No: 2306146
# Branch: IT
